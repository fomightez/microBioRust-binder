# %% [markdown]
# # Try the test according to [here](https://github.com/microBioRust/microBioRust/commit/f6fe1daf91cd4b6ea7c0656fa18bb8d81e9e386a)

# %%
# %cd microbiorust-py
# !python3 -m pytest -s tests/test_mbr.py
# Out:
# /home/jovyan/microbiorust-py
# ============================= test session starts ==============================
# platform linux -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0
# rootdir: /home/jovyan/microbiorust-py
# configfile: pyproject.toml
# plugins: anyio-4.11.0
# collected 0 items / 1 error
#
# ==================================== ERRORS ====================================
# ______________________ ERROR collecting tests/test_mbr.py ______________________
# ImportError while importing test module '/home/jovyan/microbiorust-py/tests/test_mbr.py'.
# Hint: make sure your test modules/packages have valid Python names.
# Traceback:
# /srv/conda/envs/notebook/lib/python3.10/importlib/__init__.py:126: in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# tests/test_mbr.py:3: in <module>
#     import microbiorust
# microbiorust/__init__.py:2: in <module>
#     from .microbiorust import *
# ...
