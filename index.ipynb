# %% [markdown]
# # Try the tests according to [here](https://github.com/microBioRust/microBioRust/commit/f6fe1daf91cd4b6ea7c0656fa18bb8d81e9e386a)

# %% [raw]
# %cd microbiorust-py
# !maturin develop

# %%
# %cd microbiorust-py
# !python3 -m pytest -s tests/test_mbr.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0
# rootdir: /home/jovyan/microbiorust-py
# configfile: pyproject.toml
# plugins: anyio-4.11.0
# collected 8 items
#
# tests/test_mbr.py .total records processed: 1
# .subset ['>Seq1\nATGC', '>Seq2\nATGC']
# .F...F
#
# =================================== FAILURES ===================================
# _______________________________ test_purge_gaps ________________________________
#
# mock_msa = '/tmp/pytest-of-jovyan/pytest-1/test_purge_gaps0/align.fasta'
# tmp_path = PosixPath('/tmp/pytest-of-jovyan/pytest-1/test_purge_gaps0')
#
#     def test_purge_gaps(mock_msa, tmp_path):
#         out_path = str(tmp_path / "purged.fasta")
#         #threshold 0.5 should remove the '--' columns in Seq1 and Seq2 and write to file
# >       microbiorust.purge_gaps(mock_msa, out_path, 0.5)
# ...
