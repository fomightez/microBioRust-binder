# %% [markdown]
# # Getting started with microBioRust
#
# Select a notebook from this index below to begin. If new to the package, probably start at the top.
#
# -----------

# %% [markdown]
# ### Available Notebooks
# - [Quick Demos](notebooks/demo.ipynb)
#
# #### Technical
# - [Run Tests](notebooks/run_tests.ipynb)
